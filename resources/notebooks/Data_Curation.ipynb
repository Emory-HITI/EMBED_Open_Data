# %% [markdown]
# # DATASET CURATION - MASKED ROI PROJECT
#
#
# **Objectives**:
#
# To create the following groups:
# 1. **Positive group**: BIRADS 0 that became BIRADS 3, 4, 5, 6 in the subsequent diagnostic study
# 2. **Negative group**: BIRADS 1, 2 and BIRADS 0 that became BIRADS 1, 2 in the subsequent diagnostic study

# %% [markdown]
# ## 1. Prep

# %%
import pandas as pd
import numpy as np
import random
from tqdm import tqdm

from IPython.display import display

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)

# %%
def get_stats(df, suffix=None):
    """Provides a quick summary of a dataframe."""
    try:
        print(f"DF shape: {df.shape}")
        print(f"# Patients: {df.empi_anon.nunique()}")
        print(f"# Cases: {df.acc_anon.nunique()}\n")
        print(f"# Images: {df.png_path.nunique()}\n")
    except Exception as e:
        print(e)

# %%
# EMBED
metadata_full = pd.read_csv("/data/mammo/tables/metadata_all_cohort_with_ROI_HITI.csv", dtype=str)
magview_full = pd.read_csv("/data/mammo/tables/magview_all_cohorts_anon_HITI.csv", dtype=str)

# %%
# Selecting the following columns

meta_cols = [
    "empi_anon",
    "acc_anon",
    "ImageLateralityFinal",
    "ViewPosition",
    "study_date_anon",
    "FinalImageType",
    "png_path",
    "StudyDescription",
    "match_level",
    "num_roi",
    "ROI_coords"
]

mag_cols = [
    "empi_anon",
    "acc_anon",
    "study_date_anon",
    "desc",
    "side",
    "asses",
    "path_severity",
    "bside",
    'procdate_anon',
    'pdate_anon',
]

# %%
metadata = metadata_full[meta_cols].copy()
magview = magview_full[mag_cols].copy()

# %%
metadata.study_date_anon = pd.to_datetime(metadata.study_date_anon)
magview.study_date_anon = pd.to_datetime(magview.study_date_anon)

# %%
metadata.num_roi = metadata.num_roi.astype(int)

# %% [markdown]
# ## 2. METADATA: 2D MLO & CC

# %%
# EMBED 2D (MLO and CC)
meta_2d = metadata.loc[(metadata.FinalImageType=="2D") & (metadata.ViewPosition.isin(["MLO", "CC"]))]
get_stats(meta_2d)
# Out:
# DF shape: (1645747, 11)
# # Patients: 111988
# # Cases: 355306
#
# # Images: 1645747

# %%
def get_image_stats(df):
    """Provides a quick summary of the number of unique images and the ROIs."""
    temp_df = pd.merge(df, meta_2d, on=["empi_anon", "acc_anon"], how="left")
    temp_df = temp_df.loc[
        (temp_df.side==temp_df.ImageLateralityFinal)
    ]
    temp_df.drop_duplicates(subset="png_path", inplace=True)
    print(f"# PNG PATH: {int(temp_df.png_path.nunique())}")
    print(f"# ROI: {int(temp_df.num_roi.sum())}")
    print(f"{temp_df.num_roi.value_counts()}")
    del temp_df

# %% [markdown]
# ## 3. Screening

# %%
# SCREENING
screening_magview = magview.loc[magview.desc.str.contains("screen", case=False)].copy()
get_stats(screening_magview)
# Out:
# DF shape: (311129, 10)
# # Patients: 103704
# # Cases: 295885
#
# 'DataFrame' object has no attribute 'png_path'

# %% [markdown]
# ### 3.1. Creating entries for the negative contralateral breast in bilateral examinations
#
# ```
# MAGVIEW only has entries if a finding exists.
#
# This means that if an exam is a bilateral exam and only one of the breast has a finding, the contralateral breast (negative) won't have an entry.
#
# This would be problematic at the time when we need to merge with METADATA, because the contralateral breast would be excluded.
#
# Therefore, we would need to create rows for the negative contralateral breast.
# ```

# %%
def get_exam_laterality(row):
    """A convenient function to get the exam laterality to be used with DF.apply() instead of iterating over each row."""
    if ("bilat" in row.desc.lower()):
        return "B"
    elif ("left" in row.desc.lower()):
        return "L"
    elif ("right" in row.desc.lower()):
        return "R"
    else:
        return None

# %%
# Applying the get_exam_laterality function
screening_magview["exam_laterality"] = screening_magview.apply(get_exam_laterality, axis=1)

# %%
screening_magview.exam_laterality.value_counts(dropna=False)
# Out:
# B    298848
# R      6360
# L      5921
# Name: exam_laterality, dtype: int64

# %%
screening_magview.side.value_counts(dropna=False)
# Out:
# NaN    208681
# L       43373
# R       43366
# B       15709
# Name: side, dtype: int64

# %%
# side == nan --> B
screening_magview.side = screening_magview.side.fillna("B")

# %%
# create copy for assigning B to R
screening_magview_r = screening_magview.loc[screening_magview.side=="B"].copy()
screening_magview_r.side = screening_magview.side.str.replace("B", "R")

# assigning B to L
screening_magview.side = screening_magview.side.str.replace("B", "L")

# appending R and L
screening_magview = pd.concat([screening_magview, screening_magview_r])

# %%
print(screening_magview.side.value_counts(dropna=False))
print(screening_magview.shape)
# Out:
# L    267763
# R    267756
# Name: side, dtype: int64
# (535519, 11)

# %%
screening_magview = screening_magview.sort_values(["empi_anon", "acc_anon", "study_date_anon"]).drop_duplicates()
screening_magview
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 173182  10000865  3629273638679348      2013-01-07
# 173182  10000865  3629273638679348      2013-01-07
# 31918   10000879  6992096043050201      2018-02-16
# 31918   10000879  6992096043050201      2018-02-16
# 42024   10000879  8162137067574239      2020-10-14
# ...          ...               ...             ...
# 26104   99999564  4369225803558884      2017-04-25
# 26104   99999564  4369225803558884      2017-04-25
# 31922   99999564  8832872399780580      2019-02-27
# 31922   99999564  8832872399780580      2019-02-27
# 127092  99999856  1897262968910242      2020-01-29
#
#                                             desc side asses path_severity  \
# 173182                    MG Screening Bilateral    L     B           NaN
# 173182                    MG Screening Bilateral    R     B           NaN
# 31918   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31918   MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 42024   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# ...                                          ...  ...   ...           ...
# 26104   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 26104   MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 31922   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31922   MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 127092  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     A           NaN
#
#        bside procdate_anon pdate_anon exam_laterality
# 173182   NaN           NaN        NaN               B
# 173182   NaN           NaN        NaN               B
# 31918    NaN           NaN        NaN               B
# 31918    NaN           NaN        NaN               B
# 42024    NaN           NaN        NaN               B
# ...      ...           ...        ...             ...
# 26104    NaN           NaN        NaN               B
# 26104    NaN           NaN        NaN               B
# 31922    NaN           NaN        NaN               B
# 31922    NaN           NaN        NaN               B
# 127092   NaN           NaN        NaN               B
#
# [528630 rows x 11 columns]

# %%
exam_lat_b = screening_magview.loc[screening_magview.exam_laterality=="B"]
exam_lat_b.sample(2)
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 344811  47494328  2099425055413879      2013-11-21
# 255272  40212230  5767382270904809      2021-05-07
#
#                                             desc side asses path_severity  \
# 344811              MG Screening Bilateral w/CAD    L     N           NaN
# 255272  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality
# 344811   NaN           NaN        NaN               B
# 255272   NaN           NaN        NaN               B

# %%
# We want to aggregate all the sides for each bilateral exam so that we can filter those having only a single side.
exam_lat_b_agg = exam_lat_b.groupby('acc_anon')['side'].apply(''.join).reset_index()
exam_lat_b_agg.sample(2)
# Out:
#                 acc_anon side
# 235918  8473976286914433   LR
# 48434   2539713197479326   LR

# %%
exam_lat_b_agg.side.value_counts()
# Out:
# LR         225476
# L           26501
# R           26219
# RL           3200
# LL            634
# RR            603
# LLR           400
# LRR           199
# RLR           185
# LLRR           99
# RLL            56
# RRL            53
# LLL            45
# RRR            42
# LRLR           28
# RLLR           24
# LRL            23
# RRLL           15
# LLLR            8
# RRRR            6
# RRRL            5
# RRLR            4
# LLLRRR          4
# RRLLL           3
# RLLL            3
# LRRR            3
# LLLL            2
# LRLL            2
# LRRLR           2
# LLRL            2
# RRRLL           1
# LLLRLR          1
# RRLLR           1
# LLRRR           1
# LLLLLR          1
# LRLRR           1
# LLLLRR          1
# LRRRR           1
# LLLRR           1
# RLRR            1
# LRRLL           1
# RRLLLRR         1
# RRRLLL          1
# RRRRR           1
# LRRL            1
# LRLRLR          1
# Name: side, dtype: int64

# %%
exam_lat_b_side_r = exam_lat_b_agg.loc[~(exam_lat_b_agg.side.str.contains("L"))].copy()
exam_lat_b_side_l = exam_lat_b_agg.loc[~(exam_lat_b_agg.side.str.contains("R"))].copy()

# %%
screening_magview_right_to_left = screening_magview.loc[screening_magview.acc_anon.isin(exam_lat_b_side_r.acc_anon)].copy().drop_duplicates()
screening_magview_left_to_right = screening_magview.loc[screening_magview.acc_anon.isin(exam_lat_b_side_l.acc_anon)].copy().drop_duplicates()

# %%
# Creating the negative Left side
screening_magview_right_to_left.loc[screening_magview_right_to_left.side=="R", "side"] = "L"
screening_magview_right_to_left.loc[screening_magview_right_to_left.side=="L", "asses"] = "N"
screening_magview_right_to_left.loc[screening_magview_right_to_left.side=="L", "path_severity"] = np.nan

screening_magview_right_to_left
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 161468  10001945  8351351741085824      2017-08-02
# 37799   10033806  1069386741434572      2019-10-05
# 42125   10033806  9337281572732866      2020-10-08
# 386461  10043340  8892551633769298      2020-02-06
# 66818   10043985  1960584382049532      2018-04-18
# ...          ...               ...             ...
# 283165  99975030  2279566061761287      2017-08-07
# 345671  99980000  4817391795521519      2014-02-03
# 155650  99982588  8416878517191964      2018-02-26
# 404779  99991060  5463528102254256      2016-03-08
# 200795  99993980  8474749211883423      2019-03-21
#
#                                             desc side asses path_severity  \
# 161468  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 37799   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 42125   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 386461  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 66818   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# ...                                          ...  ...   ...           ...
# 283165                    MG Screening Bilateral    L     N           NaN
# 345671              MG Screening Bilateral w/CAD    L     N           NaN
# 155650  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 404779                    MG Screening Bilateral    L     N           NaN
# 200795  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#        bside procdate_anon           pdate_anon exam_laterality
# 161468   NaN           NaN                  NaN               B
# 37799    NaN           NaN                  NaN               B
# 42125    NaN           NaN                  NaN               B
# 386461   NaN           NaN                  NaN               B
# 66818    NaN           NaN                  NaN               B
# ...      ...           ...                  ...             ...
# 283165   NaN           NaN                  NaN               B
# 345671   NaN           NaN                  NaN               B
# 155650   NaN           NaN                  NaN               B
# 404779     R    2016-03-28  2016-03-29 00:00:00               B
# 200795   NaN           NaN                  NaN               B
#
# [27580 rows x 11 columns]

# %%
# Creating the negative Right side
screening_magview_left_to_right.loc[screening_magview_left_to_right.side=="L", "side"] = "R"
screening_magview_left_to_right.loc[screening_magview_left_to_right.side=="R", "asses"] = "N"
screening_magview_left_to_right.loc[screening_magview_left_to_right.side=="R", "path_severity"] = np.nan

screening_magview_left_to_right
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 266782  10002247  4667123741504672      2015-02-04
# 391750  10010842  2152357467079057      2014-07-05
# 20834   10015693  1334581155737139      2015-10-11
# 403309  10019705  1199638332134935      2016-06-08
# 425750  10019705  3384492963323757      2020-07-19
# ...          ...               ...             ...
# 263656  99985035  9268129462152986      2014-09-11
# 29702   99986224  8107409307566891      2018-05-22
# 240347  99986388  1665558280896604      2017-10-01
# 202020  99997273  2996543584580499      2018-09-13
# 127092  99999856  1897262968910242      2020-01-29
#
#                                             desc side asses path_severity  \
# 266782                    MG Screening Bilateral    R     N           NaN
# 391750  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 20834   MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 403309  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 425750  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# ...                                          ...  ...   ...           ...
# 263656  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 29702   MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 240347  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 202020  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 127092  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#        bside procdate_anon           pdate_anon exam_laterality
# 266782   NaN           NaN                  NaN               B
# 391750     L    2014-07-18  2014-07-18 00:00:00               B
# 20834    NaN           NaN                  NaN               B
# 403309   NaN           NaN                  NaN               B
# 425750   NaN           NaN                  NaN               B
# ...      ...           ...                  ...             ...
# 263656   NaN           NaN                  NaN               B
# 29702    NaN           NaN                  NaN               B
# 240347   NaN           NaN                  NaN               B
# 202020   NaN           NaN                  NaN               B
# 127092   NaN           NaN                  NaN               B
#
# [27912 rows x 11 columns]

# %%
# Merging the original and the two negative contralaterals
screening_magview_with_contralat = pd.concat([screening_magview, screening_magview_left_to_right, screening_magview_right_to_left]).sort_values(["empi_anon", "acc_anon", "study_date_anon"]).drop_duplicates()
screening_magview_with_contralat.sample(2)
# Out:
#        empi_anon          acc_anon study_date_anon                    desc  \
# 296187  44132453  1473567328233293      2019-08-11  MG Screening Bilateral
# 322144  20812558  3290510072755021      2016-03-01  MG Screening Bilateral
#
#        side asses path_severity bside procdate_anon pdate_anon exam_laterality
# 296187    L     N           NaN   NaN           NaN        NaN               B
# 322144    R     N           NaN   NaN           NaN        NaN               B

# %%
get_image_stats(screening_magview_with_contralat)
# Out:
# # PNG PATH: 1298290
# # ROI: 25879
# 0.0    1274855
# 1.0      21185
# 2.0       2060
# 3.0        186
# 4.0          4
# Name: num_roi, dtype: int64

# %% [markdown]
# ### 3.2. BIRADS 0

# %%
b0 = screening_magview_with_contralat.loc[screening_magview_with_contralat.asses.isin(["A"])]

get_stats(b0)
get_image_stats(b0)
# Out:
# DF shape: (56790, 11)
# # Patients: 40331
# # Cases: 46292
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 123773
# # ROI: 25308
# 0.0    100868
# 1.0     20687
# 2.0      2037
# 3.0       177
# 4.0         4
# Name: num_roi, dtype: int64

# %% [markdown]
# ### 3.3. BIRADS 1, 2

# %%
b12 = screening_magview_with_contralat.loc[screening_magview_with_contralat.asses.isin(["B", "N"])]

get_stats(b12)
get_image_stats(b12)
# Out:
# DF shape: (526770, 11)
# # Patients: 99792
# # Cases: 286134
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 1177163
# # ROI: 1006
# 0.0    1176248
# 1.0        840
# 2.0         59
# 3.0         16
# Name: num_roi, dtype: int64

# %% [markdown]
# ## 4. Diagnostic

# %%
diag_magview = magview.loc[magview.desc.str.contains('diag', case=False)]

get_stats(diag_magview)
print()
print(f"Asses Counts:\n{diag_magview.asses.value_counts()}")
# Out:
# DF shape: (117842, 10)
# # Patients: 49420
# # Cases: 87494
#
# 'DataFrame' object has no attribute 'png_path'
#
# Asses Counts:
# B    45655
# P    28500
# N    21452
# S    15455
# A     2908
# K     2094
# M     1667
# X      111
# Name: asses, dtype: int64

# %% [markdown]
# ## 5. Screening BIRADS 0 and Diagnostic

# %%
b0_dx = pd.merge(b0, diag_magview, on='empi_anon', suffixes=[None, "_dx"])
b0_dx = b0_dx.loc[
    (b0_dx.side==b0_dx.side_dx)
    | (b0_dx.side_dx=="B")
    | (b0_dx.side_dx.isna())
]

# %%
# Getting only subsequent diagnostic studies within 3 months
b0_dx["delta_date_dx"] = (b0_dx.study_date_anon_dx - b0_dx.study_date_anon).dt.days
b0_dx_3mo = b0_dx.loc[b0_dx.delta_date_dx.isin(range(0, 91))]
b0_dx_3mo.sample(1)
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 111674  99071319  4291883356856064      2018-02-08
#
#                                             desc side asses path_severity  \
# 111674  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     A           NaN
#
#        bside procdate_anon pdate_anon exam_laterality       acc_anon_dx  \
# 111674   NaN           NaN        NaN               B  9034500297208086
#
#        study_date_anon_dx                    desc_dx side_dx asses_dx  \
# 111674         2018-02-26  MG Diagnostic Right w/CAD       R        B
#
#        path_severity_dx bside_dx procdate_anon_dx pdate_anon_dx  delta_date_dx
# 111674              NaN      NaN              NaN           NaN             18

# %% [markdown]
# ### 5.1. BIRADS 0 (Screening) --> BIRADS 1, 2 (Diagnostic)

# %%
b0_12dx = b0_dx_3mo.loc[b0_dx_3mo.asses_dx.isin(["N", "B"])].copy()
get_stats(b0_12dx)
get_image_stats(b0_12dx)
# Out:
# DF shape: (19967, 21)
# # Patients: 15602
# # Cases: 16961
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 40123
# # ROI: 8519
# 0.0    32591
# 1.0     6607
# 2.0      864
# 3.0       60
# 4.0        1
# Name: num_roi, dtype: int64

# %% [markdown]
# ### 5.2. BIRADS 0 (Screening) --> BIRADS 3, 4, 5, 6 (Diagnostic)

# %%
b0_3456dx = b0_dx_3mo.loc[b0_dx_3mo.asses_dx.isin(["P", "S", "M", "K"])].copy()
get_stats(b0_3456dx)
get_image_stats(b0_3456dx)
# Out:
# DF shape: (18343, 21)
# # Patients: 11177
# # Cases: 11710
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 28625
# # ROI: 7214
# 0.0    22146
# 1.0     5817
# 2.0      591
# 3.0       69
# 4.0        2
# Name: num_roi, dtype: int64

# %% [markdown]
# ## 6. Negative group

# %%
# Negative group = BIRADS_12 + BIRADS_0_12dx
neg_group = pd.concat([b12, b0_12dx])
neg_group.drop_duplicates(inplace=True)

get_stats(neg_group)
get_image_stats(neg_group)
# Out:
# DF shape: (545663, 21)
# # Patients: 100783
# # Cases: 289024
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 1216280
# # ROI: 9382
# 0.0    1207956
# 1.0       7343
# 2.0        905
# 3.0         75
# 4.0          1
# Name: num_roi, dtype: int64

# %%
# Include only ones with negative follow-up after 1 year
neg_group_b12 = pd.merge(neg_group, b12, on=["empi_anon"], suffixes=(None, "_1yrfu"))

neg_group_b12 = neg_group_b12.loc[
    (neg_group_b12.side==neg_group_b12.side_1yrfu)
]

neg_group_b12["delta_date_1yrfu"] = (neg_group_b12.study_date_anon_1yrfu - neg_group_b12.study_date_anon).dt.days

get_stats(neg_group_b12)
get_image_stats(neg_group_b12)

neg_group_b12.sample(2)
# Out:
# DF shape: (2329305, 32)
# # Patients: 99792
# # Cases: 288000
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 1206833
# # ROI: 6851
# 0.0    1200713
# 1.0       5437
# 2.0        636
# 3.0         46
# 4.0          1
# Name: num_roi, dtype: int64
#         empi_anon          acc_anon study_date_anon  \
# 1251954  34595437  3721150955690973      2013-08-08
# 3488116  78037395  7295645242502555      2019-08-22
#
#                                              desc side asses path_severity  \
# 1251954              MG Screening Bilateral w/CAD    R     N           NaN
# 3488116  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#         bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 1251954   NaN           NaN        NaN               B         NaN
# 3488116   NaN           NaN        NaN               B         NaN
#
#         study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 1251954                NaT     NaN     NaN      NaN              NaN      NaN
# 3488116                NaT     NaN     NaN      NaN              NaN      NaN
#
#         procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 1251954              NaN           NaN            NaN  4047169165502113
# 3488116              NaN           NaN            NaN  7295645242502555
#
#         study_date_anon_1yrfu                                desc_1yrfu  \
# 1251954            2016-09-02  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 3488116            2019-08-22  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#         side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 1251954          R           N                 NaN         NaN
# 3488116          R           N                 NaN         NaN
#
#         procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 1251954                 NaN              NaN                     B
# 3488116                 NaN              NaN                     B
#
#          delta_date_1yrfu
# 1251954              1121
# 3488116                 0

# %%
neg_group_1yrfu = neg_group_b12.loc[
    (neg_group_b12.delta_date_1yrfu > 360)
]
get_stats(neg_group_1yrfu)
get_image_stats(neg_group_1yrfu)
# Out:
# DF shape: (892822, 32)
# # Patients: 60473
# # Cases: 185352
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 813568
# # ROI: 4213
# 0.0    809806
# 1.0      3348
# 2.0       378
# 3.0        35
# 4.0         1
# Name: num_roi, dtype: int64

# %%
neg_group_1yrfu_first_study = neg_group_1yrfu.sort_values(["empi_anon", "acc_anon", "study_date_anon_1yrfu"]).drop_duplicates(subset=["acc_anon", "side"]) # to only get the first followup study
get_stats(neg_group_1yrfu_first_study)
get_image_stats(neg_group_1yrfu_first_study)
# Out:
# DF shape: (346327, 32)
# # Patients: 60473
# # Cases: 185352
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 813568
# # ROI: 4213
# 0.0    809806
# 1.0      3348
# 2.0       378
# 3.0        35
# 4.0         1
# Name: num_roi, dtype: int64

# %%
neg_group_1yrfu_first_study.path_severity.value_counts()
# Out:
# 4.0    172
# 2.0     52
# 0.0     37
# 1.0     13
# 3.0      2
# 5.0      2
# Name: path_severity, dtype: int64

# %%
# Exclude any patient with any biopsy result
neg_group_1yrfu_first_study_no_biopsy = neg_group_1yrfu_first_study.loc[neg_group_1yrfu_first_study.path_severity.isna()].copy()

# %%
# Merging with METADATA to get the images
neg_group_1yrfu_first_study_no_biopsy_images = pd.merge(neg_group_1yrfu_first_study_no_biopsy, meta_2d, on=["empi_anon", "acc_anon", "study_date_anon"])
neg_group_1yrfu_first_study_no_biopsy_images = neg_group_1yrfu_first_study_no_biopsy_images.loc[
    (neg_group_1yrfu_first_study_no_biopsy_images.side == neg_group_1yrfu_first_study_no_biopsy_images.ImageLateralityFinal)
]
neg_group_1yrfu_first_study_no_biopsy_images.drop_duplicates(subset="png_path", inplace=True)
get_stats(neg_group_1yrfu_first_study_no_biopsy_images)
# Out:
# DF shape: (807779, 40)
# # Patients: 58261
# # Cases: 178934
#
# # Images: 807779

# %%
print(f"ROIs = {neg_group_1yrfu_first_study_no_biopsy_images.num_roi.sum()}")
print(neg_group_1yrfu_first_study_no_biopsy_images.num_roi.value_counts())
# Out:
# ROIs = 4089
# 0    804117
# 1      3269
# 2       360
# 3        32
# 4         1
# Name: num_roi, dtype: int64

# %% [markdown]
# ## 7. Positive Group

# %%
pos_group_images = pd.merge(b0_3456dx, meta_2d, on=["empi_anon", "acc_anon", "study_date_anon"])
pos_group_images = pos_group_images.loc[
    (pos_group_images.side == pos_group_images.ImageLateralityFinal)
]
pos_group_images.drop_duplicates(subset="png_path", inplace=True)
get_stats(pos_group_images)
# Out:
# DF shape: (28496, 29)
# # Patients: 10557
# # Cases: 11022
#
# # Images: 28496

# %%
print(f"ROIs  = {pos_group_images.num_roi.sum()}")
print(pos_group_images.num_roi.value_counts())
# Out:
# ROIs  = 7204
# 0    22025
# 1     5811
# 2      589
# 3       69
# 4        2
# Name: num_roi, dtype: int64

# %% [markdown]
# ## 8. Excluding Images from the Negative Group that are found in the Positive Group using acc_anon and side

# %%
# Merge negatives and positive groups
neg_pos = pd.merge(neg_group_1yrfu_first_study_no_biopsy_images, pos_group_images, on=["empi_anon", "acc_anon", "side"], suffixes=["_neg", "_pos"])
neg_pos.sample(2)
# Out:
#     empi_anon          acc_anon study_date_anon_neg  \
# 760  34789855  6476608733007008          2014-04-01
# 360  19703500  8975983036689789          2014-12-15
#
#                                      desc_neg side asses_neg  \
# 760              MG Screening Left w/Tomo/CAD    L         A
# 360  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L         B
#
#     path_severity_neg bside_neg procdate_anon_neg pdate_anon_neg  \
# 760               NaN       NaN               NaN            NaN
# 360               NaN       NaN               NaN            NaN
#
#     exam_laterality_neg   acc_anon_dx_neg study_date_anon_dx_neg  \
# 760                   L  8993781340339809             2014-04-21
# 360                   B               NaN                    NaT
#
#                   desc_dx_neg side_dx_neg asses_dx_neg path_severity_dx_neg  \
# 760  MG Diagnostic Left w/CAD           L            B                  NaN
# 360                       NaN         NaN          NaN                  NaN
#
#     bside_dx_neg procdate_anon_dx_neg pdate_anon_dx_neg  delta_date_dx_neg  \
# 760          NaN                  NaN               NaN               20.0
# 360          NaN                  NaN               NaN                NaN
#
#        acc_anon_1yrfu study_date_anon_1yrfu  \
# 760  9992904429283646            2016-07-13
# 360  4273910518306474            2015-12-19
#
#                                    desc_1yrfu side_1yrfu asses_1yrfu  \
# 760              MG Screening Left w/Tomo/CAD          L           N
# 360  MG Screen Bilat w/Tomo/CAD Stnd Protocol          L           B
#
#     path_severity_1yrfu bside_1yrfu procdate_anon_1yrfu pdate_anon_1yrfu  \
# 760                 NaN         NaN                 NaN              NaN
# 360                 NaN         NaN                 NaN              NaN
#
#     exam_laterality_1yrfu  delta_date_1yrfu ImageLateralityFinal_neg  \
# 760                     L               834                        L
# 360                     B               369                        L
#
#     ViewPosition_neg FinalImageType_neg  \
# 760               CC                 2D
# 360              MLO                 2D
#
#                                           png_path_neg  \
# 760  /data/mammo/png/cohort_9/extracted-images/f500...
# 360  /data/mammo/png/cohort_1/extracted-images/52f9...
#
#                          StudyDescription_neg match_level_neg  num_roi_neg  \
# 760              MG Screening Left w/Tomo/CAD              []            0
# 360  MG Screen Bilat w/Tomo/CAD Stnd Protocol              []            0
#
#     ROI_coords_neg study_date_anon_pos  \
# 760             ()          2014-04-01
# 360             ()          2014-12-15
#
#                                      desc_pos asses_pos path_severity_pos  \
# 760              MG Screening Left w/Tomo/CAD         A               NaN
# 360  MG Screen Bilat w/Tomo/CAD Stnd Protocol         A               4.0
#
#     bside_pos procdate_anon_pos       pdate_anon_pos exam_laterality_pos  \
# 760       NaN               NaN                  NaN                   L
# 360         L        2014-12-25  2014-12-26 00:00:00                   B
#
#       acc_anon_dx_pos study_date_anon_dx_pos               desc_dx_pos  \
# 760  8993781340339809             2014-04-21  MG Diagnostic Left w/CAD
# 360  3343455609167761             2014-12-20  MG Diagnostic Left w/CAD
#
#     side_dx_pos asses_dx_pos path_severity_dx_pos bside_dx_pos  \
# 760           L            P                  NaN          NaN
# 360           L            S                  4.0            L
#
#     procdate_anon_dx_pos    pdate_anon_dx_pos  delta_date_dx_pos  \
# 760                  NaN                  NaN                 20
# 360           2014-12-25  2014-12-26 00:00:00                  5
#
#     ImageLateralityFinal_pos ViewPosition_pos FinalImageType_pos  \
# 760                        L              MLO                 2D
# 360                        L               CC                 2D
#
#                                           png_path_pos  \
# 760  /data/mammo/png/cohort_9/extracted-images/f500...
# 360  /data/mammo/png/cohort_1/extracted-images/52f9...
#
#                          StudyDescription_pos match_level_pos  num_roi_pos  \
# 760              MG Screening Left w/Tomo/CAD              []            0
# 360  MG Screen Bilat w/Tomo/CAD Stnd Protocol              []            0
#
#     ROI_coords_pos
# 760             ()
# 360             ()

# %%
# Create new KeyID of acc_anon + side on negative group and negative+positive group
neg_pos["acc_anon_side"] = neg_pos.acc_anon + neg_pos.side
neg_pos.sample(2)
# Out:
#      empi_anon          acc_anon study_date_anon_neg  \
# 1043  43961961  5243068495140390          2013-02-05
# 399   22680085  9748736436676015          2016-07-25
#
#                                       desc_neg side asses_neg  \
# 1043              MG Screening Bilateral w/CAD    L         A
# 399   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L         A
#
#      path_severity_neg bside_neg procdate_anon_neg pdate_anon_neg  \
# 1043               NaN       NaN               NaN            NaN
# 399                NaN       NaN               NaN            NaN
#
#      exam_laterality_neg   acc_anon_dx_neg study_date_anon_dx_neg  \
# 1043                   B  1335360084337623             2013-03-04
# 399                    B  9677750844499584             2016-07-31
#
#              desc_dx_neg side_dx_neg asses_dx_neg path_severity_dx_neg  \
# 1043  MG Diagnostic Left           L            B                  NaN
# 399   MG Diagnostic Left           L            B                  NaN
#
#      bside_dx_neg procdate_anon_dx_neg pdate_anon_dx_neg  delta_date_dx_neg  \
# 1043          NaN                  NaN               NaN               27.0
# 399           NaN                  NaN               NaN                6.0
#
#         acc_anon_1yrfu study_date_anon_1yrfu  \
# 1043  4149785248271308            2016-04-30
# 399   3326862674671184            2019-09-30
#
#                                     desc_1yrfu side_1yrfu asses_1yrfu  \
# 1043  MG Screen Bilat w/Tomo/CAD Stnd Protocol          L           N
# 399   MG Screen Bilat w/Tomo/CAD Stnd Protocol          L           N
#
#      path_severity_1yrfu bside_1yrfu procdate_anon_1yrfu pdate_anon_1yrfu  \
# 1043                 NaN         NaN                 NaN              NaN
# 399                  NaN         NaN                 NaN              NaN
#
#      exam_laterality_1yrfu  delta_date_1yrfu ImageLateralityFinal_neg  \
# 1043                     B              1180                        L
# 399                      B              1162                        L
#
#      ViewPosition_neg FinalImageType_neg  \
# 1043              MLO                 2D
# 399               MLO                 2D
#
#                                            png_path_neg  \
# 1043  /data/mammo/png/cohort_5/extracted-images/527f...
# 399   /data/mammo/png/cohort_10/extracted-images/533...
#
#                     StudyDescription_neg match_level_neg  num_roi_neg  \
# 1043        MG Screening Bilateral w/CAD              []            0
# 399   MG Screening Digital BL w/Tomo/CAD              []            0
#
#      ROI_coords_neg study_date_anon_pos  \
# 1043             ()          2013-02-05
# 399              ()          2016-07-25
#
#                                       desc_pos asses_pos path_severity_pos  \
# 1043              MG Screening Bilateral w/CAD         A               NaN
# 399   MG Screen Bilat w/Tomo/CAD Stnd Protocol         A               NaN
#
#      bside_pos procdate_anon_pos pdate_anon_pos exam_laterality_pos  \
# 1043       NaN               NaN            NaN                   B
# 399        NaN               NaN            NaN                   B
#
#        acc_anon_dx_pos study_date_anon_dx_pos                    desc_dx_pos  \
# 1043  7485410784607630             2013-03-02  MG Diagnostic Mammo Bilateral
# 399   9677750844499584             2016-07-31             MG Diagnostic Left
#
#      side_dx_pos asses_dx_pos path_severity_dx_pos bside_dx_pos  \
# 1043           L            S                  NaN          NaN
# 399            L            P                  NaN          NaN
#
#      procdate_anon_dx_pos pdate_anon_dx_pos  delta_date_dx_pos  \
# 1043                  NaN               NaN                 25
# 399                   NaN               NaN                  6
#
#      ImageLateralityFinal_pos ViewPosition_pos FinalImageType_pos  \
# 1043                        L               CC                 2D
# 399                         L               CC                 2D
#
#                                            png_path_pos  \
# 1043  /data/mammo/png/cohort_5/extracted-images/527f...
# 399   /data/mammo/png/cohort_10/extracted-images/533...
#
#                     StudyDescription_pos match_level_pos  num_roi_pos  \
# 1043        MG Screening Bilateral w/CAD              []            0
# 399   MG Screening Digital BL w/Tomo/CAD              []            0
#
#      ROI_coords_pos      acc_anon_side
# 1043             ()  5243068495140390L
# 399              ()  9748736436676015L

# %%
neg_group_1yrfu_first_study_no_biopsy_images["acc_anon_side"] = neg_group_1yrfu_first_study_no_biopsy_images.acc_anon + neg_group_1yrfu_first_study_no_biopsy_images.side
neg_group_1yrfu_first_study_no_biopsy_images.sample(2)
# Out:
#         empi_anon          acc_anon study_date_anon  \
# 885604   59718570  2415163519747488      2014-06-17
# 1279860  81763266  2409705155300596      2018-12-27
#
#                                              desc side asses path_severity  \
# 885604   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 1279860  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#         bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 885604    NaN           NaN        NaN               B         NaN
# 1279860   NaN           NaN        NaN               B         NaN
#
#         study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 885604                 NaT     NaN     NaN      NaN              NaN      NaN
# 1279860                NaT     NaN     NaN      NaN              NaN      NaN
#
#         procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 885604               NaN           NaN            NaN  6969519729345303
# 1279860              NaN           NaN            NaN  2090480540250219
#
#         study_date_anon_1yrfu                                desc_1yrfu  \
# 885604             2015-06-17  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 1279860            2020-05-17  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#         side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 885604           L           N                 NaN         NaN
# 1279860          L           N                 NaN         NaN
#
#         procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 885604                  NaN              NaN                     B
# 1279860                 NaN              NaN                     B
#
#          delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 885604                365                    L           CC             2D
# 1279860               507                    L           CC             2D
#
#                                                   png_path  \
# 885604   /data/mammo/png/cohort_7/extracted-images/5867...
# 1279860  /data/mammo/png/cohort_8/extracted-images/8be0...
#
#                                  StudyDescription match_level  num_roi  \
# 885604   MG Screen Bilat w/Tomo/CAD Stnd Protocol          []        0
# 1279860  MG Screen Bilat w/Tomo/CAD Stnd Protocol          []        0
#
#         ROI_coords      acc_anon_side
# 885604          ()  2415163519747488L
# 1279860         ()  2409705155300596L

# %%
# Removing any images that are found in the positive group from the negative group using the created KeyID (acc_anon+side)
neg_group_final = neg_group_1yrfu_first_study_no_biopsy_images.loc[~neg_group_1yrfu_first_study_no_biopsy_images.acc_anon_side.isin(neg_pos.acc_anon_side)]
neg_group_final.sample(2)
# Out:
#         empi_anon          acc_anon study_date_anon  \
# 1043917  68580524  8507037717396147      2016-12-11
# 67272    13784788  9704448443602447      2019-10-23
#
#                                              desc side asses path_severity  \
# 1043917                    MG Screening Bilateral    L     N           NaN
# 67272    MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     A           NaN
#
#         bside procdate_anon pdate_anon exam_laterality       acc_anon_dx  \
# 1043917   NaN           NaN        NaN               B               NaN
# 67272     NaN           NaN        NaN               B  4035300999545663
#
#         study_date_anon_dx                    desc_dx side_dx asses_dx  \
# 1043917                NaT                        NaN     NaN      NaN
# 67272           2019-11-04  MG Diagnostic Right w/CAD       R        B
#
#         path_severity_dx bside_dx procdate_anon_dx pdate_anon_dx  \
# 1043917              NaN      NaN              NaN           NaN
# 67272                NaN      NaN              NaN           NaN
#
#          delta_date_dx    acc_anon_1yrfu study_date_anon_1yrfu  \
# 1043917            NaN  9344738692043744            2018-03-04
# 67272             12.0  5935121117587892            2021-03-01
#
#                                        desc_1yrfu side_1yrfu asses_1yrfu  \
# 1043917              MG Screening Bilateral w/CAD          L           N
# 67272    MG Screen Bilat w/Tomo/CAD Stnd Protocol          R           N
#
#         path_severity_1yrfu bside_1yrfu procdate_anon_1yrfu pdate_anon_1yrfu  \
# 1043917                 NaN         NaN                 NaN              NaN
# 67272                   NaN         NaN                 NaN              NaN
#
#         exam_laterality_1yrfu  delta_date_1yrfu ImageLateralityFinal  \
# 1043917                     B               448                    L
# 67272                       B               495                    R
#
#         ViewPosition FinalImageType  \
# 1043917          MLO             2D
# 67272            MLO             2D
#
#                                                   png_path  \
# 1043917  /data/mammo/png/cohort_3/extracted-images/5940...
# 67272    /data/mammo/png/cohort_3/extracted-images/dac3...
#
#                                  StudyDescription match_level  num_roi  \
# 1043917                    MG Screening Bilateral          []        0
# 67272    MG Screen Bilat w/Tomo/CAD Stnd Protocol         [1]        1
#
#                         ROI_coords      acc_anon_side
# 1043917                         ()  8507037717396147L
# 67272    ((1447, 171, 1905, 501),)  9704448443602447R

# %%
get_stats(neg_group_final)

print(f"ROIs  = {neg_group_final.num_roi.sum()}")
print(neg_group_final.num_roi.value_counts())
# Out:
# DF shape: (806676, 41)
# # Patients: 58233
# # Cases: 178854
#
# # Images: 806676
#
# ROIs  = 3878
# 0    803184
# 1      3136
# 2       327
# 3        28
# 4         1
# Name: num_roi, dtype: int64

# %% [markdown]
# ## 9. Saving and Exporting

# %%
columns_to_save = [
    'empi_anon',
    'acc_anon',
    'desc',
    'asses',
    'asses_dx',
    'path_severity',
    'study_date_anon',
    'study_date_anon_dx',
    'side',
    'ImageLateralityFinal',
    'bside',
    'ViewPosition',
    'match_level',
    'num_roi',
    'ROI_coords',
    'png_path',
]

# %%
break
neg_group_final[columns_to_save].to_csv("NEGATIVE_GROUP.csv", index=False)

# %%
break
pos_group_images[columns_to_save].to_csv("POSITIVE_GROUP.csv", index=False)
# Out:
#   Cell In[77], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# # END
